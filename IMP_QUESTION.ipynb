# %% [markdown]
# <a href="https://colab.research.google.com/github/rm17octo22/PYTHON/blob/main/IMP_QUESTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ######################   imp topics  ###############################
#
# 1.) what is DA v/s DS ???
#
# 2.) what is insight ???
#
# 3.) what is doignastic v/s predictive ???
#
# 4.) what is compiler v/s intreputer ???
#
# 5.) what is cloud ???
#
# 6.) what is PEMADAS rule ???
#
# 7.) what is mutable v/s immutable ???
#
# 8.) what is buffer memory ???
#
# 9.) difference between = and == .
#
# 10.) difference between len(),range(),indexing,slicing.
#
# 11.)what is difference between intruputer and compiler ????
#
# 12.) how many data types in python and describe here.
#
# 13.) primitive data types v/s non-premitive data types .
#
# 14.) what is identifier ???
#
# 15.) what is difference between function and method ???
#
# 16.) what is mongodb ???
#
# 17.) what is case senstivive ???
#
# 18.) what is difference between all datatypes ???
#
# 19.) what is unicode ???
#
# 20.) difference between x = 7 v/s x += 7
#
# 21.) what is difference between typecasting(),eval() and input() ???
#
# 22.) what is CRUD rules ???
#
# 23.) .append() v/s .extend()
#
# 24.) .sort() v/s sorted()
#
# 25.) .pop() v/s .remove()
#
# 26.) deep copy v/s shellow copy (clone) (hint:- .append and .copy)
#
# 27.)  simple statement v/s compound statement
#
# 28.) what is indention ???
#
# 29.) what is limitiation of for loops ??? --->>> int,float not allowed.
#
# 30.) how to use for loop and where ???
#
# 31.) explain more about on for loop ???
#
# 32.) how to identify question of for loop and after identify how to solve ???
#
# 33.) explain more about on while loop ???
#
# 34.) how to solve question of while loop ???
#
# 35.) how to identify which loop(for/while) is best for question solving ???
#
# 36.) difference between while loop and for loop ???
#
# 37.) difference between print v/s retuen ???
#
# 38.) what is function and how to use ???
#
# 39.) what is difference between range() and slicing[] ???
#
# 40.) print() v/s return ???
#
# 41.) map () v/s filter () ???
#
# 42.) how to comment multiple line at that one time --->> select + ctrl + /
#
# 43.)
#
#
#
#
#
#
#
# ERROR :
#
# 1.) identition error : dependency of statement (conditions)
#                        (proper spacing ...if,if...else,nested if..else)
#
# 2.)TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# 3.)TypeError: 'int' object is not iterable --->>> in for loop int,float not
#                                                  directly acces for itretion
#
# 4.)ValueError: not enough values to unpack (expected 3, got 2)
#       |
#       |
#       ------- for with zip () ---->>> not same values (len) are both variable
#
# 5.)ValueError: too many values to unpack (expected 2)
#       |
#       |
#       ------- for with zip () ---->>> not matching ratio of variable and values
#
# 6.)
#
#
#
#
#
#
# NOTE :
#
# 1.) indexing start counting with zero(0).
#
# 2.) length start counting with one(1).
#
# 3.) range start counting with zero(0).
#
# 4.) loops always used for block of elements ...like str,list,tuple,set,dict .
